# %% [markdown]
# <h2 style='color: #4A90E2; background: linear-gradient(135deg, #E3F2FD 0%, #BBDEFB 100%); padding: 15px; border-radius: 8px; border-left: 5px solid #2196F3;'>📚 Introduction to Dictionaries</h2>
#
# <p style='color: #555; font-size: 14px; line-height: 1.6;'>This cell demonstrates <strong style='color: #E91E63;'>unlabeled data</strong> stored in a list. We'll see how dictionaries can help organize this data with labels.</p>

# %%
info = ["noha", 33, "iti", "engineering"]  # unlabeled data

# %% [markdown]
# <h2 style='color: #4A90E2; background: linear-gradient(135deg, #E3F2FD 0%, #BBDEFB 100%); padding: 15px; border-radius: 8px; border-left: 5px solid #2196F3;'>🔨 Creating a Dictionary</h2>
#
# <p style='color: #555; font-size: 14px; line-height: 1.6;'>This cell shows how to create a dictionary with <strong style='color: #E91E63;'>key-value pairs</strong>. Dictionaries use <em style='color: #9C27B0;'>hashing</em> to store keys efficiently.</p>

# %%
# represent data --> add labels
# dict ?? --> use hashing in saving keys
"""
dict is comma seperated Key:value  ==> key unique
"""

d = {}
myd = dict()

# %% [markdown]
# <h2 style='color: #4A90E2; background: linear-gradient(135deg, #E3F2FD 0%, #BBDEFB 100%); padding: 15px; border-radius: 8px; border-left: 5px solid #2196F3;'>✏️ Updating Dictionary Values</h2>
#
# <p style='color: #555; font-size: 14px; line-height: 1.6;'>This cell demonstrates how to <strong style='color: #E91E63;'>update existing dictionary values</strong> by accessing keys. If the key exists, its value is updated.</p>

# %%
info = {"name":"Ahmed", "Track": "Ai", "city": "mansoura"}

# %% [markdown]
# <h2 style='color: #4A90E2; background: linear-gradient(135deg, #E3F2FD 0%, #BBDEFB 100%); padding: 15px; border-radius: 8px; border-left: 5px solid #2196F3;'>➕ Adding New Key-Value Pairs</h2>
#
# <p style='color: #555; font-size: 14px; line-height: 1.6;'>This cell shows how to <strong style='color: #E91E63;'>add new key-value pairs</strong> to an existing dictionary by assigning to a new key.</p>

# %%
# dict is mutable
# access content --> using keys ??
# update values of keys
info["name"]="Ahmed Mohamed" # if key exists update
print(info)
# Out:
# {'name': 'Ahmed Mohamed', 'Track': 'Ai', 'city': 'mansoura'}

# %% [markdown]
# <h2 style='color: #4A90E2; background: linear-gradient(135deg, #E3F2FD 0%, #BBDEFB 100%); padding: 15px; border-radius: 8px; border-left: 5px solid #2196F3;'>🔑 Accessing Dictionary Keys</h2>
#
# <p style='color: #555; font-size: 14px; line-height: 1.6;'>This cell demonstrates how to access dictionary keys using the <code style='background: #F5F5F5; padding: 2px 6px; border-radius: 3px; color: #D32F2F;'>.keys()</code> method, which returns a <strong style='color: #E91E63;'>view object</strong> that can be converted to a list.</p>

# %%
info["salary"]= 4000  # # add new pairs to the dict ??

# %% [markdown]
# <h2 style='color: #4A90E2; background: linear-gradient(135deg, #E3F2FD 0%, #BBDEFB 100%); padding: 15px; border-radius: 8px; border-left: 5px solid #2196F3;'>💎 Accessing Dictionary Values</h2>
#
# <p style='color: #555; font-size: 14px; line-height: 1.6;'>This cell shows how to access dictionary values using the <code style='background: #F5F5F5; padding: 2px 6px; border-radius: 3px; color: #D32F2F;'>.values()</code> method, which returns a <strong style='color: #E91E63;'>view object</strong> containing all values.</p>

# %%
# dict is mutable
# access dict keys, access dict values ??

keys = info.keys()
print(keys)
keys_l = list(keys)
# Out:
# dict_keys(['name', 'Track', 'city', 'salary'])

# %% [markdown]
# <h2 style='color: #4A90E2; background: linear-gradient(135deg, #E3F2FD 0%, #BBDEFB 100%); padding: 15px; border-radius: 8px; border-left: 5px solid #2196F3;'>📦 Accessing Dictionary Items</h2>
#
# <p style='color: #555; font-size: 14px; line-height: 1.6;'>This cell demonstrates how to access both <strong style='color: #E91E63;'>keys and values together</strong> using the <code style='background: #F5F5F5; padding: 2px 6px; border-radius: 3px; color: #D32F2F;'>.items()</code> method, which returns key-value pairs as <em style='color: #9C27B0;'>tuples</em>.</p>

# %% [markdown]
# <h2 style='color: #4A90E2; background: linear-gradient(135deg, #E3F2FD 0%, #BBDEFB 100%); padding: 15px; border-radius: 8px; border-left: 5px solid #2196F3;'>📦 Accessing Dictionary Items</h2>
#
# <p style='color: #555; font-size: 14px; line-height: 1.6;'>This cell demonstrates how to access both <strong style='color: #E91E63;'>keys and values together</strong> using the <code style='background: #F5F5F5; padding: 2px 6px; border-radius: 3px; color: #D32F2F;'>.items()</code> method, which returns key-value pairs as <em style='color: #9C27B0;'>tuples</em>.</p>
# he

# %% [markdown]
# <h2 style='color: #4A90E2; background: linear-gradient(135deg, #E3F2FD 0%, #BBDEFB 100%); padding: 15px; border-radius: 8px; border-left: 5px solid #2196F3;'>🔄 Converting Dictionary Items to List</h2>
#
# <p style='color: #555; font-size: 14px; line-height: 1.6;'>This cell shows how to <strong style='color: #E91E63;'>convert the dictionary items view object</strong> into a list of tuples.</p>

# %%
values= info.values()
print(values)
# Out:
# dict_values(['Ahmed Mohamed', 'Ai', 'mansoura', 4000])

# %% [markdown]
# <h2 style='color: #4A90E2; background: linear-gradient(135deg, #E3F2FD 0%, #BBDEFB 100%); padding: 15px; border-radius: 8px; border-left: 5px solid #2196F3;'>🔄 Iterating Over Dictionary Keys</h2>
#
# <p style='color: #555; font-size: 14px; line-height: 1.6;'>This cell demonstrates <strong style='color: #E91E63;'>iterating over a dictionary</strong>, which by default iterates over the keys.</p>

# %% [markdown]
# er

# %%
items = info.items()
print(items)
# Out:
# dict_items([('name', 'Ahmed Mohamed'), ('Track', 'Ai'), ('city', 'mansoura'), ('salary', 4000)])

# %% [markdown]
# ed a

# %% [markdown]
# <h2 style='color: #4A90E2; background: linear-gradient(135deg, #E3F2FD 0%, #BBDEFB 100%); padding: 15px; border-radius: 8px; border-left: 5px solid #2196F3;'>🔄 Updating Dictionary with Another Dictionary</h2>
#
# <p style='color: #555; font-size: 14px; line-height: 1.6;'>This cell demonstrates the <code style='background: #F5F5F5; padding: 2px 6px; border-radius: 3px; color: #D32F2F;'>.update()</code> method, which <strong style='color: #E91E63;'>merges another dictionary</strong> into the current one, updating existing keys and adding new ones.</p>

# %%
d_items = list(items)
print(d_items)
# Out:
# [('name', 'Ahmed Mohamed'), ('Track', 'Ai'), ('city', 'mansoura'), ('salary', 4000)]

# %% [markdown]
# <h2 style='color: #4A90E2; background: linear-gradient(135deg, #E3F2FD 0%, #BBDEFB 100%); padding: 15px; border-radius: 8px; border-left: 5px solid #2196F3;'>🔄 Iterating Over Keys and Values</h2>
#
# <p style='color: #555; font-size: 14px; line-height: 1.6;'>This cell shows how to <strong style='color: #E91E63;'>iterate over dictionary keys</strong> and access their corresponding values using the key as an index.</p>

# %%
for i in info:
    print(f"i= {i}")
# Out:
# i= name
# i= Track
# i= city
# i= salary

# %% [markdown]
# e

# %%
for i  in info:
    print(f"{i}, {info[i]}")
# Out:
# name, Ahmed Mohamed
# Track, Ai
# city, mansoura
# salary, 4000

# %% [markdown]
# <h2 style='color: #4A90E2; background: linear-gradient(135deg, #E3F2FD 0%, #BBDEFB 100%); padding: 15px; border-radius: 8px; border-left: 5px solid #2196F3;'>🔍 Checking Membership in Dictionary</h2>
#
# <p style='color: #555; font-size: 14px; line-height: 1.6;'>This cell shows how to check if a value exists in a dictionary. <strong style='color: #FF9800;'>⚠️ Note:</strong> the <code style='background: #F5F5F5; padding: 2px 6px; border-radius: 3px; color: #D32F2F;'>in</code> operator checks <em style='color: #9C27B0;'>keys</em>, not values.</p>

# %%
### update dict ??
add_info = {
    "city":"Cairo",
    "hoppy": "Reading"
}
print(info)
info.update(add_info)
print(info)
# Out:
# {'name': 'Ahmed Mohamed', 'Track': 'Ai', 'city': 'mansoura', 'salary': 4000}
# {'name': 'Ahmed Mohamed', 'Track': 'Ai', 'city': 'Cairo', 'salary': 4000, 'hoppy': 'Reading'}

# %% [markdown]
# <h2 style='color: #4A90E2; background: linear-gradient(135deg, #E3F2FD 0%, #BBDEFB 100%); padding: 15px; border-radius: 8px; border-left: 5px solid #2196F3;'>📏 Getting Dictionary Length</h2>
#
# <p style='color: #555; font-size: 14px; line-height: 1.6;'>This cell demonstrates how to get the <strong style='color: #E91E63;'>number of key-value pairs</strong> in a dictionary using the <code style='background: #F5F5F5; padding: 2px 6px; border-radius: 3px; color: #D32F2F;'>len()</code> function.</p>

# %%
print("Ai" in info ) # search in keys
# Out:
# False

# %% [markdown]
# <h2 style='color: #4A90E2; background: linear-gradient(135deg, #E3F2FD 0%, #BBDEFB 100%); padding: 15px; border-radius: 8px; border-left: 5px solid #2196F3;'>🗑️ Clearing Dictionary Contents</h2>
#
# <p style='color: #555; font-size: 14px; line-height: 1.6;'>This cell shows how to <strong style='color: #E91E63;'>remove all items</strong> from a dictionary using the <code style='background: #F5F5F5; padding: 2px 6px; border-radius: 3px; color: #D32F2F;'>.clear()</code> method.</p>

# %%
# len of dict
print(len(info))
# Out:
# 5

# %% [markdown]
# <h2 style='color: #4A90E2; background: linear-gradient(135deg, #E3F2FD 0%, #BBDEFB 100%); padding: 15px; border-radius: 8px; border-left: 5px solid #2196F3;'>🗑️ Clearing a List</h2>
#
# <p style='color: #555; font-size: 14px; line-height: 1.6;'>This cell demonstrates that the <code style='background: #F5F5F5; padding: 2px 6px; border-radius: 3px; color: #D32F2F;'>.clear()</code> method also works on <strong style='color: #E91E63;'>lists</strong> to remove all elements.</p>

# %%
# tips
info.clear()
print(info)
# Out:
# {}

# %% [markdown]
# <h2 style='color: #4A90E2; background: linear-gradient(135deg, #E3F2FD 0%, #BBDEFB 100%); padding: 15px; border-radius: 8px; border-left: 5px solid #2196F3;'>✅ Verifying Dictionary is Cleared</h2>
#
# <p style='color: #555; font-size: 14px; line-height: 1.6;'>This cell checks that the dictionary has been <strong style='color: #4CAF50;'>successfully cleared</strong> and is now empty.</p>

# %%
l = [234,235,5,True]

# %% [markdown]
# <h2 style='color: #4A90E2; background: linear-gradient(135deg, #E3F2FD 0%, #BBDEFB 100%); padding: 15px; border-radius: 8px; border-left: 5px solid #2196F3;'>🆕 Creating a New Dictionary</h2>
#
# <p style='color: #555; font-size: 14px; line-height: 1.6;'>This cell creates a <strong style='color: #E91E63;'>fresh dictionary</strong> with new key-value pairs.</p>

# %%
l.clear()

# %% [markdown]
# <h2 style='color: #4A90E2; background: linear-gradient(135deg, #E3F2FD 0%, #BBDEFB 100%); padding: 15px; border-radius: 8px; border-left: 5px solid #2196F3;'>❌ Deleting Dictionary Items</h2>
#
# <p style='color: #555; font-size: 14px; line-height: 1.6;'>This cell demonstrates how to <strong style='color: #E91E63;'>delete a specific key-value pair</strong> from a dictionary using the <code style='background: #F5F5F5; padding: 2px 6px; border-radius: 3px; color: #D32F2F;'>del</code> statement.</p>

# %%
print(info)
# Out:
# {}

# %%
info  ={"name": "Mariam", "track": "Ai"}

# %%
del info["track"]
