# %%
print("Tuples")

# %% [markdown]
# <h2 style='color: #4CAF50; background: linear-gradient(135deg, #E8F5E9 0%, #C8E6C9 100%); padding: 15px; border-radius: 8px; border-left: 5px solid #388E3C;'>📋 Defining Tuples</h2>
#
# <p style='color: #555; font-size: 14px; line-height: 1.6;'>This cell demonstrates how to create an <strong style='color: #E91E63;'>empty tuple</strong> using parentheses <code style='background: #F5F5F5; padding: 2px 6px; border-radius: 3px; color: #D32F2F;'>()</code> or the <code style='background: #F5F5F5; padding: 2px 6px; border-radius: 3px; color: #D32F2F;'>tuple()</code> constructor.</p>

# %%
# can hold many values

# 1- define a tuple ?
l = ()
myt = tuple()

# %% [markdown]
# <h2 style='color: #4CAF50; background: linear-gradient(135deg, #E8F5E9 0%, #C8E6C9 100%); padding: 15px; border-radius: 8px; border-left: 5px solid #388E3C;'>📦 Tuples with Mixed Data Types</h2>
#
# <p style='color: #555; font-size: 14px; line-height: 1.6;'>This cell shows that tuples can hold <strong style='color: #E91E63;'>different data types</strong> including numbers, strings, booleans, nested lists, and None values.</p>

# %%
# 2- can hold different values f
myt= (234, "iti", "iti", True,["python", "ML"], None, 423.23434)

# %% [markdown]
# <h2 style='color: #4CAF50; background: linear-gradient(135deg, #E8F5E9 0%, #C8E6C9 100%); padding: 15px; border-radius: 8px; border-left: 5px solid #388E3C;'>🔢 Accessing Tuple Elements by Index</h2>
#
# <p style='color: #555; font-size: 14px; line-height: 1.6;'>This cell demonstrates accessing tuple elements using <strong style='color: #E91E63;'>index notation</strong>. Tuple indices start from 0, just like lists.</p>

# %%
# 3- each element has index --> start from zero
# access content, using index, slicing
print(myt[3])
# Out:
# True

# %% [markdown]
# <h2 style='color: #4CAF50; background: linear-gradient(135deg, #E8F5E9 0%, #C8E6C9 100%); padding: 15px; border-radius: 8px; border-left: 5px solid #388E3C;'>✂️ Tuple Slicing</h2>
#
# <p style='color: #555; font-size: 14px; line-height: 1.6;'>This cell demonstrates <strong style='color: #E91E63;'>tuple slicing</strong>, which creates a new tuple containing elements from a specified range.</p>

# %%
print(myt[4:]) # new tuple
# Out:
# (['python', 'ML'], None, 423.23434)

# %% [markdown]
# <h2 style='color: #4CAF50; background: linear-gradient(135deg, #E8F5E9 0%, #C8E6C9 100%); padding: 15px; border-radius: 8px; border-left: 5px solid #388E3C;'>🔍 Accessing Nested Tuple Elements</h2>
#
# <p style='color: #555; font-size: 14px; line-height: 1.6;'>This cell shows how to access elements in <strong style='color: #E91E63;'>nested structures</strong> within tuples using multiple index levels.</p>

# %%
print(myt[4][1])
# Out:
# ML

# %% [markdown]
# <h2 style='color: #4CAF50; background: linear-gradient(135deg, #E8F5E9 0%, #C8E6C9 100%); padding: 15px; border-radius: 8px; border-left: 5px solid #388E3C;'>💡 Modifying Mutable Elements in Tuple</h2>
#
# <p style='color: #555; font-size: 14px; line-height: 1.6;'>This cell demonstrates that while tuples are <strong style='color: #E91E63;'>immutable</strong>, you can modify <em style='color: #9C27B0;'>mutable objects</em> (like lists) that are elements of a tuple.</p>

# %% [markdown]
# <h2 style='color: #4CAF50; background: linear-gradient(135deg, #E8F5E9 0%, #C8E6C9 100%); padding: 15px; border-radius: 8px; border-left: 5px solid #388E3C;'>🔢 Counting Elements in Tuple</h2>
#
# <p style='color: #555; font-size: 14px; line-height: 1.6;'>This cell demonstrates the <code style='background: #F5F5F5; padding: 2px 6px; border-radius: 3px; color: #D32F2F;'>.count()</code> method, which returns the <strong style='color: #E91E63;'>number of occurrences</strong> of a specific value in the tuple.</p>

# %%
print(myt[4])
myt[4].append("Deep learning")
print(myt)
# Out:
# ['python', 'ML', 'Deep learning']
# (234, 'iti', 'iti', True, ['python', 'ML', 'Deep learning', 'Deep learning'], None, 423.23434)

# %% [markdown]
# <h2 style='color: #4CAF50; background: linear-gradient(135deg, #E8F5E9 0%, #C8E6C9 100%); padding: 15px; border-radius: 8px; border-left: 5px solid #388E3C;'>📏 Getting Tuple Length</h2>
#
# <p style='color: #555; font-size: 14px; line-height: 1.6;'>This cell demonstrates using the <code style='background: #F5F5F5; padding: 2px 6px; border-radius: 3px; color: #D32F2F;'>len()</code> function to get the <strong style='color: #E91E63;'>number of elements</strong> in a tuple.</p>

# %%
# count, len, index,
print(myt.count("iti"))
# Out:
# 2

# %% [markdown]
# <h2 style='color: #4CAF50; background: linear-gradient(135deg, #E8F5E9 0%, #C8E6C9 100%); padding: 15px; border-radius: 8px; border-left: 5px solid #388E3C;'>🔍 Checking Membership in Tuple</h2>
#
# <p style='color: #555; font-size: 14px; line-height: 1.6;'>This cell demonstrates using the <code style='background: #F5F5F5; padding: 2px 6px; border-radius: 3px; color: #D32F2F;'>in</code> operator to check if a value <strong style='color: #E91E63;'>exists in the tuple</strong>.</p>

# %%
print(len(myt ))
# Out:
# 7

# %% [markdown]
# <h2 style='color: #4CAF50; background: linear-gradient(135deg, #E8F5E9 0%, #C8E6C9 100%); padding: 15px; border-radius: 8px; border-left: 5px solid #388E3C;'>💾 Checking Memory Size</h2>
#
# <p style='color: #555; font-size: 14px; line-height: 1.6;'>This cell demonstrates using <code style='background: #F5F5F5; padding: 2px 6px; border-radius: 3px; color: #D32F2F;'>sys.getsizeof()</code> to check the <strong style='color: #E91E63;'>memory size</strong> of tuples in bytes. Tuples are generally more memory-efficient than lists.</p>

# %%
print("noha" in myt)
# Out:
# False

# %% [markdown]
# <h2 style='color: #4CAF50; background: linear-gradient(135deg, #E8F5E9 0%, #C8E6C9 100%); padding: 15px; border-radius: 8px; border-left: 5px solid #388E3C;'>⚠️ Tuples are Immutable</h2>
#
# <p style='color: #555; font-size: 14px; line-height: 1.6;'><strong style='color: #FF9800;'>⚠️ Error Example:</strong> This cell demonstrates that tuples are <em style='color: #9C27B0;'>immutable</em> - you cannot modify tuple elements directly. This will raise a TypeError.</p>

# %%
import sys
print(sys.getsizeof(l))

print(sys.getsizeof(myt))
# Out:
# 40
# 96

# %% [markdown]
# <h1>Tuples are immutable ?? </h1>

# %%
# update value at index
myt[1]='updated'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 2
#       1 # update value at index
# ----> 2 myt[1]='updated'
#
# TypeError: 'tuple' object does not support item assignment

# %% [markdown]
# <h2 style='color: #4CAF50; background: linear-gradient(135deg, #E8F5E9 0%, #C8E6C9 100%); padding: 15px; border-radius: 8px; border-left: 5px solid #388E3C;'>🔄 Iterating Over Tuple Elements</h2>
#
# <p style='color: #555; font-size: 14px; line-height: 1.6;'>This cell demonstrates using a <code style='background: #F5F5F5; padding: 2px 6px; border-radius: 3px; color: #D32F2F;'>for</code> loop to <strong style='color: #E91E63;'>iterate over all elements</strong> in a tuple with manual index tracking.</p>

# %% [markdown]
# <h2 style='color: #4CAF50; background: linear-gradient(135deg, #E8F5E9 0%, #C8E6C9 100%); padding: 15px; border-radius: 8px; border-left: 5px solid #388E3C;'>🔢 Using enumerate() with Tuples</h2>
#
# <p style='color: #555; font-size: 14px; line-height: 1.6;'>This cell demonstrates the <code style='background: #F5F5F5; padding: 2px 6px; border-radius: 3px; color: #D32F2F;'>enumerate()</code> function with tuples, which returns an <strong style='color: #E91E63;'>enumerate object</strong> with index-value pairs.</p>

# %% [markdown]
# <h2 style='color: #4CAF50; background: linear-gradient(135deg, #E8F5E9 0%, #C8E6C9 100%); padding: 15px; border-radius: 8px; border-left: 5px solid #388E3C;'>🔄 Iterating with enumerate()</h2>
#
# <p style='color: #555; font-size: 14px; line-height: 1.6;'>This cell demonstrates how to use <code style='background: #F5F5F5; padding: 2px 6px; border-radius: 3px; color: #D32F2F;'>enumerate()</code> in a loop to get both <strong style='color: #E91E63;'>index and value</strong> simultaneously from a tuple.</p>

# %% [markdown]
# <h2 style='color: #4CAF50; background: linear-gradient(135deg, #E8F5E9 0%, #C8E6C9 100%); padding: 15px; border-radius: 8px; border-left: 5px solid #388E3C;'>🔗 Concatenating Tuples</h2>
#
# <p style='color: #555; font-size: 14px; line-height: 1.6;'>This cell demonstrates <strong style='color: #E91E63;'>concatenating two tuples</strong> using the <code style='background: #F5F5F5; padding: 2px 6px; border-radius: 3px; color: #D32F2F;'>+</code> operator, which creates a new tuple.</p>

# %% [markdown]
# <h2 style='color: #4CAF50; background: linear-gradient(135deg, #E8F5E9 0%, #C8E6C9 100%); padding: 15px; border-radius: 8px; border-left: 5px solid #388E3C;'>📊 Finding Minimum Value</h2>
#
# <p style='color: #555; font-size: 14px; line-height: 1.6;'>This cell demonstrates using the <code style='background: #F5F5F5; padding: 2px 6px; border-radius: 3px; color: #D32F2F;'>min()</code> function to find the <strong style='color: #E91E63;'>smallest value</strong> in a tuple.</p>

# %%
# enumarate ?
counter = 0
for item in myt:
    print(f"{counter}: {item}")
    counter +=1
# Out:
# 0: 234
# 1: iti
# 2: iti
# 3: True
# 4: ['python', 'ML', 'Deep learning', 'Deep learning']
# 5: None
# 6: 423.23434

# %% [markdown]
# <h2 style='color: #4CAF50; background: linear-gradient(135deg, #E8F5E9 0%, #C8E6C9 100%); padding: 15px; border-radius: 8px; border-left: 5px solid #388E3C;'>💡 Converting String to Tuple</h2>
#
# <p style='color: #555; font-size: 14px; line-height: 1.6;'>This cell demonstrates the difference: <code style='background: #F5F5F5; padding: 2px 6px; border-radius: 3px; color: #D32F2F;'>tuple(string)</code> creates a tuple of <strong style='color: #E91E63;'>individual characters</strong>, while <code style='background: #F5F5F5; padding: 2px 6px; border-radius: 3px; color: #D32F2F;'>[string]</code> creates a list with the <em style='color: #9C27B0;'>entire string</em> as one element.</p>

# %%
mylenum = enumerate(myt)
print(mylenum)

# %% [markdown]
# <h2 style='color: #4CAF50; background: linear-gradient(135deg, #E8F5E9 0%, #C8E6C9 100%); padding: 15px; border-radius: 8px; border-left: 5px solid #388E3C;'>🔗 Joining Tuple Elements into String</h2>
#
# <p style='color: #555; font-size: 14px; line-height: 1.6;'>This cell demonstrates the <code style='background: #F5F5F5; padding: 2px 6px; border-radius: 3px; color: #D32F2F;'>.join()</code> method, which <strong style='color: #E91E63;'>combines tuple elements</strong> into a single string using a specified separator.</p>

# %%
for index, item in mylenum:
    print(index, item )
# Out:
# 0 234
# 1 iti
# 2 iti
# 3 True
# 4 ['python', 'ML', 'Deep learning', 'Deep learning']
# 5 None
# 6 423.23434

# %% [markdown]
# <h2 style='color: #4CAF50; background: linear-gradient(135deg, #E8F5E9 0%, #C8E6C9 100%); padding: 15px; border-radius: 8px; border-left: 5px solid #388E3C;'>⚠️ Single Element Tuple Syntax</h2>
#
# <p style='color: #555; font-size: 14px; line-height: 1.6;'><strong style='color: #FF9800;'>⚠️ Common Mistake:</strong> This cell shows that <code style='background: #F5F5F5; padding: 2px 6px; border-radius: 3px; color: #D32F2F;'>(10)</code> is just an integer, not a tuple. You need a <em style='color: #9C27B0;'>trailing comma</em> to create a single-element tuple.</p>

# %%
for index, item in mylenum:
    print(index, item )

# %% [markdown]
# <h2 style='color: #4CAF50; background: linear-gradient(135deg, #E8F5E9 0%, #C8E6C9 100%); padding: 15px; border-radius: 8px; border-left: 5px solid #388E3C;'>✅ Correct Single Element Tuple</h2>
#
# <p style='color: #555; font-size: 14px; line-height: 1.6;'>This cell shows the <strong style='color: #4CAF50;'>correct syntax</strong> for creating a single-element tuple: <code style='background: #F5F5F5; padding: 2px 6px; border-radius: 3px; color: #D32F2F;'>(10,)</code> with a trailing comma.</p>

# %% [markdown]
# <h2 style='color: #4CAF50; background: linear-gradient(135deg, #E8F5E9 0%, #C8E6C9 100%); padding: 15px; border-radius: 8px; border-left: 5px solid #388E3C;'>⚠️ tuple() Constructor with Integer</h2>
#
# <p style='color: #555; font-size: 14px; line-height: 1.6;'><strong style='color: #FF9800;'>⚠️ Error Example:</strong> This cell demonstrates that <code style='background: #F5F5F5; padding: 2px 6px; border-radius: 3px; color: #D32F2F;'>tuple(10)</code> will raise a TypeError because integers are not iterable.</p>

# %% [markdown]
# <h2 style='color: #4CAF50; background: linear-gradient(135deg, #E8F5E9 0%, #C8E6C9 100%); padding: 15px; border-radius: 8px; border-left: 5px solid #388E3C;'>✅ tuple() Constructor with List</h2>
#
# <p style='color: #555; font-size: 14px; line-height: 1.6;'>This cell shows the <strong style='color: #4CAF50;'>correct usage</strong> of <code style='background: #F5F5F5; padding: 2px 6px; border-radius: 3px; color: #D32F2F;'>tuple()</code> constructor with an iterable (list) to create a tuple.</p>

# %%
# concat
m = ("abc", True, 40 ,66)
n = ("python", "test", "iti", 88)
z = m + n
print(z)
# Out:
# ('abc', True, 40, 66, 'python', 'test', 'iti', 88)

# %% [markdown]
# <h2 style='color: #4CAF50; background: linear-gradient(135deg, #E8F5E9 0%, #C8E6C9 100%); padding: 15px; border-radius: 8px; border-left: 5px solid #388E3C;'>⚠️ tuple() with Parentheses</h2>
#
# <p style='color: #555; font-size: 14px; line-height: 1.6;'><strong style='color: #FF9800;'>⚠️ Note:</strong> This cell demonstrates that <code style='background: #F5F5F5; padding: 2px 6px; border-radius: 3px; color: #D32F2F;'>tuple((10))</code> still creates an integer, not a tuple, because the inner parentheses are just for grouping.</p>

# %%
x = (5,66,77)
print(min(x))
# Out:
# 5

# %%
# tip
name = 'ahmed'
name1 = tuple(name)
print(name1)
name2 = [name]
print(name2)
# Out:
# ('a', 'h', 'm', 'e', 'd')
# ['ahmed']

# %%
#
users= ("ahmed", "Mohamed", "Ali", "data")
# convert tuple elements to one string
print("-".join(users))
# Out:
# ahmed-Mohamed-Ali-data

# %%
# tuple of one element
tt =(10)
print(type(tt))
# Out:
# <class 'int'>

# %%
tt =(10,)
print(type(tt))
# Out:
# <class 'tuple'>

# %%
tt =tuple(10)
print(type(tt))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 tt =tuple(10)
#       2 print(type(tt))
#
# TypeError: 'int' object is not iterable

# %%
tt =tuple([10])
print(type(tt), tt)
# Out:
# <class 'tuple'> (10,)

# %%
tt =tuple((10))
print(type(tt), tt)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 tt =tuple((10))
#       2 print(type(tt), tt)
#
# TypeError: 'int' object is not iterable
