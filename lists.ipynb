# %%
print("Lists")
# Out:
# Lists

# %% [markdown]
# <h2 style='color: #9B59B6; background: linear-gradient(135deg, #F3E5F5 0%, #E1BEE7 100%); padding: 15px; border-radius: 8px; border-left: 5px solid #9C27B0;'>📋 Defining Lists</h2>
#
# <p style='color: #555; font-size: 14px; line-height: 1.6;'>This cell demonstrates how to create an <strong style='color: #E91E63;'>empty list</strong> using two methods: square brackets <code style='background: #F5F5F5; padding: 2px 6px; border-radius: 3px; color: #D32F2F;'>[]</code> or the <code style='background: #F5F5F5; padding: 2px 6px; border-radius: 3px; color: #D32F2F;'>list()</code> constructor.</p>

# %%
# the most popular data type in python,
# can hold many values

# 1- define a list ?
l = []
myl = list()

# %% [markdown]
# <h2 style='color: #9B59B6; background: linear-gradient(135deg, #F3E5F5 0%, #E1BEE7 100%); padding: 15px; border-radius: 8px; border-left: 5px solid #9C27B0;'>📦 Lists with Mixed Data Types</h2>
#
# <p style='color: #555; font-size: 14px; line-height: 1.6;'>This cell shows that lists can hold <strong style='color: #E91E63;'>different data types</strong> including numbers, strings, booleans, nested lists, and None values.</p>

# %%
# 2- can hold different values f
myl= [234, "iti", "iti", True,["python", "ML"], None, 423.23434]

# %% [markdown]
# <h2 style='color: #9B59B6; background: linear-gradient(135deg, #F3E5F5 0%, #E1BEE7 100%); padding: 15px; border-radius: 8px; border-left: 5px solid #9C27B0;'>🔢 Accessing List Elements by Index</h2>
#
# <p style='color: #555; font-size: 14px; line-height: 1.6;'>This cell demonstrates accessing list elements using <strong style='color: #E91E63;'>index notation</strong>. List indices start from 0.</p>

# %%
# 3- each element has index --> start from zero
# access content, using index, slicing
print(myl[3])
# Out:
# True

# %% [markdown]
# <h2 style='color: #9B59B6; background: linear-gradient(135deg, #F3E5F5 0%, #E1BEE7 100%); padding: 15px; border-radius: 8px; border-left: 5px solid #9C27B0;'>✂️ List Slicing</h2>
#
# <p style='color: #555; font-size: 14px; line-height: 1.6;'>This cell demonstrates <strong style='color: #E91E63;'>list slicing</strong>, which creates a new list containing elements from a specified range.</p>

# %%
print(myl[4:]) # new list
# Out:
# [['python', 'ML'], None, 423.23434]

# %% [markdown]
# <h2 style='color: #9B59B6; background: linear-gradient(135deg, #F3E5F5 0%, #E1BEE7 100%); padding: 15px; border-radius: 8px; border-left: 5px solid #9C27B0;'>🔍 Accessing Nested List Elements</h2>
#
# <p style='color: #555; font-size: 14px; line-height: 1.6;'>This cell shows how to access elements in <strong style='color: #E91E63;'>nested lists</strong> using multiple index levels.</p>

# %%
print(myl[4][1])
# Out:
# ML

# %% [markdown]
# <h2 style='color: #9B59B6; background: linear-gradient(135deg, #F3E5F5 0%, #E1BEE7 100%); padding: 15px; border-radius: 8px; border-left: 5px solid #9C27B0;'>🔢 Counting Elements in List</h2>
#
# <p style='color: #555; font-size: 14px; line-height: 1.6;'>This cell demonstrates the <code style='background: #F5F5F5; padding: 2px 6px; border-radius: 3px; color: #D32F2F;'>.count()</code> method, which returns the <strong style='color: #E91E63;'>number of occurrences</strong> of a specific value in the list.</p>

# %%
# count, len, index,
print(myl.count("iti"))
# Out:
# 2

# %% [markdown]
# <h2 style='color: #9B59B6; background: linear-gradient(135deg, #F3E5F5 0%, #E1BEE7 100%); padding: 15px; border-radius: 8px; border-left: 5px solid #9C27B0;'>📏 Getting List Length</h2>
#
# <p style='color: #555; font-size: 14px; line-height: 1.6;'>This cell demonstrates using the <code style='background: #F5F5F5; padding: 2px 6px; border-radius: 3px; color: #D32F2F;'>len()</code> function to get the <strong style='color: #E91E63;'>number of elements</strong> in a list.</p>

# %%
print(len(myl ))
# Out:
# 7

# %% [markdown]
# <h2 style='color: #9B59B6; background: linear-gradient(135deg, #F3E5F5 0%, #E1BEE7 100%); padding: 15px; border-radius: 8px; border-left: 5px solid #9C27B0;'>🔍 Checking Membership in List</h2>
#
# <p style='color: #555; font-size: 14px; line-height: 1.6;'>This cell demonstrates using the <code style='background: #F5F5F5; padding: 2px 6px; border-radius: 3px; color: #D32F2F;'>in</code> operator to check if a value <strong style='color: #E91E63;'>exists in the list</strong>.</p>

# %%
print("noha" in myl)
# Out:
# False

# %% [markdown]
# <h2 style='color: #9B59B6; background: linear-gradient(135deg, #F3E5F5 0%, #E1BEE7 100%); padding: 15px; border-radius: 8px; border-left: 5px solid #9C27B0;'>💾 Checking Memory Size</h2>
#
# <p style='color: #555; font-size: 14px; line-height: 1.6;'>This cell demonstrates using <code style='background: #F5F5F5; padding: 2px 6px; border-radius: 3px; color: #D32F2F;'>sys.getsizeof()</code> to check the <strong style='color: #E91E63;'>memory size</strong> of lists in bytes.</p>

# %%
import sys
print(sys.getsizeof(l))

print(sys.getsizeof(myl))
# Out:
# 56
# 112

# %% [markdown]
# <h2 style='color: #9B59B6; background: linear-gradient(135deg, #F3E5F5 0%, #E1BEE7 100%); padding: 15px; border-radius: 8px; border-left: 5px solid #9C27B0;'>✏️ Updating List Elements</h2>
#
# <p style='color: #555; font-size: 14px; line-height: 1.6;'>This cell demonstrates that lists are <strong style='color: #E91E63;'>mutable</strong> - you can update values at specific indices.</p>

# %% [markdown]
# <h1>MuTABLE Operations</h1>

# %% [markdown]
# <h2 style='color: #9B59B6; background: linear-gradient(135deg, #F3E5F5 0%, #E1BEE7 100%); padding: 15px; border-radius: 8px; border-left: 5px solid #9C27B0;'>➕ Adding Elements with append()</h2>
#
# <p style='color: #555; font-size: 14px; line-height: 1.6;'>This cell demonstrates the <code style='background: #F5F5F5; padding: 2px 6px; border-radius: 3px; color: #D32F2F;'>.append()</code> method, which <strong style='color: #E91E63;'>adds an element</strong> to the end of the list.</p>

# %%
# update value at index
myl[1]='updated'

# %% [markdown]
# <h2 style='color: #9B59B6; background: linear-gradient(135deg, #F3E5F5 0%, #E1BEE7 100%); padding: 15px; border-radius: 8px; border-left: 5px solid #9C27B0;'>📌 Inserting Elements at Specific Position</h2>
#
# <p style='color: #555; font-size: 14px; line-height: 1.6;'>This cell demonstrates the <code style='background: #F5F5F5; padding: 2px 6px; border-radius: 3px; color: #D32F2F;'>.insert()</code> method, which <strong style='color: #E91E63;'>inserts an element</strong> at a specific index position.</p>

# %%
# 1- append
myl.append("Ahmed")
print(myl)
# Out:
# [234, 'iti', 'iti', True, ['python', 'ML'], None, 423.23434, 'Ahmed']

# %% [markdown]
# <h2 style='color: #9B59B6; background: linear-gradient(135deg, #F3E5F5 0%, #E1BEE7 100%); padding: 15px; border-radius: 8px; border-left: 5px solid #9C27B0;'>🗑️ Removing Elements with pop()</h2>
#
# <p style='color: #555; font-size: 14px; line-height: 1.6;'>This cell demonstrates the <code style='background: #F5F5F5; padding: 2px 6px; border-radius: 3px; color: #D32F2F;'>.pop()</code> method, which <strong style='color: #E91E63;'>removes and returns</strong> the last element (or element at specified index).</p>

# %%
# 2- insert
myl.insert(3, "new value")

# %% [markdown]
# <h2 style='color: #9B59B6; background: linear-gradient(135deg, #F3E5F5 0%, #E1BEE7 100%); padding: 15px; border-radius: 8px; border-left: 5px solid #9C27B0;'>🗑️ Removing Elements with remove()</h2>
#
# <p style='color: #555; font-size: 14px; line-height: 1.6;'>This cell demonstrates the <code style='background: #F5F5F5; padding: 2px 6px; border-radius: 3px; color: #D32F2F;'>.remove()</code> method, which <strong style='color: #E91E63;'>removes the first occurrence</strong> of a specified value. Returns None.</p>

# %%
# 3- pop
v= myl.pop() # return popped value
print(v)
# Out:
# Ahmed

# %% [markdown]
# <h2 style='color: #9B59B6; background: linear-gradient(135deg, #F3E5F5 0%, #E1BEE7 100%); padding: 15px; border-radius: 8px; border-left: 5px solid #9C27B0;'>🔤 Sorting List Elements</h2>
#
# <p style='color: #555; font-size: 14px; line-height: 1.6;'>This cell demonstrates the <code style='background: #F5F5F5; padding: 2px 6px; border-radius: 3px; color: #D32F2F;'>.sort()</code> method, which <strong style='color: #E91E63;'>sorts the list in place</strong>. Elements must be of the same type for comparison.</p>

# %%
# pop at index
print(myl.pop(4))
# Out:
# True

# %% [markdown]
# <h2 style='color: #9B59B6; background: linear-gradient(135deg, #F3E5F5 0%, #E1BEE7 100%); padding: 15px; border-radius: 8px; border-left: 5px solid #9C27B0;'>🔄 Reversing List Order</h2>
#
# <p style='color: #555; font-size: 14px; line-height: 1.6;'>This cell demonstrates the <code style='background: #F5F5F5; padding: 2px 6px; border-radius: 3px; color: #D32F2F;'>.reverse()</code> method, which <strong style='color: #E91E63;'>reverses the order</strong> of elements in the list in place.</p>

# %%
# I need to remove specific val ?
print(myl.remove("iti")) # first occ.
# this function return with none
# Out:
# None

# %% [markdown]
# <h2 style='color: #9B59B6; background: linear-gradient(135deg, #F3E5F5 0%, #E1BEE7 100%); padding: 15px; border-radius: 8px; border-left: 5px solid #9C27B0;'>🔗 Extending List with Another List</h2>
#
# <p style='color: #555; font-size: 14px; line-height: 1.6;'>This cell demonstrates the <code style='background: #F5F5F5; padding: 2px 6px; border-radius: 3px; color: #D32F2F;'>.extend()</code> method, which <strong style='color: #E91E63;'>adds all elements</strong> from another list to the current list.</p>

# %%
# sort list elements ==> elements must be from the same datatype
courses = ["python", 'Ml', 'Linear', "Generative", 'Deep learning']
print(courses)
courses.sort() # asc,
# courses.sort(reverse=True)
print(courses)
# Out:
# ['python', 'Ml', 'Linear', 'Generative', 'Deep learning']
# ['Deep learning', 'Generative', 'Linear', 'Ml', 'python']

# %% [markdown]
# <h2 style='color: #9B59B6; background: linear-gradient(135deg, #F3E5F5 0%, #E1BEE7 100%); padding: 15px; border-radius: 8px; border-left: 5px solid #9C27B0;'>📦 Appending List as Single Element</h2>
#
# <p style='color: #555; font-size: 14px; line-height: 1.6;'>This cell shows the difference: <code style='background: #F5F5F5; padding: 2px 6px; border-radius: 3px; color: #D32F2F;'>.append()</code> adds the entire list as a <strong style='color: #E91E63;'>single nested element</strong>, unlike extend().</p>

# %%
# reverse =--> in same variables
print(myl)
myl.reverse()
print(myl)
# Out:
# [234, 'iti', 'new value', ['python', 'ML'], None, 423.23434]
# [423.23434, None, ['python', 'ML'], 'new value', 'iti', 234]

# %% [markdown]
# <h2 style='color: #9B59B6; background: linear-gradient(135deg, #F3E5F5 0%, #E1BEE7 100%); padding: 15px; border-radius: 8px; border-left: 5px solid #9C27B0;'>🔄 Iterating Over List Elements</h2>
#
# <p style='color: #555; font-size: 14px; line-height: 1.6;'>This cell demonstrates using a <code style='background: #F5F5F5; padding: 2px 6px; border-radius: 3px; color: #D32F2F;'>for</code> loop to <strong style='color: #E91E63;'>iterate over all elements</strong> in a list.</p>

# %%
# extend list ?
workshops = ["Commun.", 'PS', 'Tesing']
myl.extend(workshops)
print(myl)

# myl.append(workshops)
# Out:
# [423.23434, None, ['python', 'ML'], 'new value', 'iti', 234, 'Commun.', 'PS', 'Tesing']

# %% [markdown]
# <h2 style='color: #9B59B6; background: linear-gradient(135deg, #F3E5F5 0%, #E1BEE7 100%); padding: 15px; border-radius: 8px; border-left: 5px solid #9C27B0;'>🔢 Manual Index Tracking in Loop</h2>
#
# <p style='color: #555; font-size: 14px; line-height: 1.6;'>This cell demonstrates manually tracking the <strong style='color: #E91E63;'>index counter</strong> while iterating over list elements.</p>

# %%
myl.append(workshops)

# %% [markdown]
# <h2 style='color: #9B59B6; background: linear-gradient(135deg, #F3E5F5 0%, #E1BEE7 100%); padding: 15px; border-radius: 8px; border-left: 5px solid #9C27B0;'>🔢 Using enumerate() Function</h2>
#
# <p style='color: #555; font-size: 14px; line-height: 1.6;'>This cell demonstrates the <code style='background: #F5F5F5; padding: 2px 6px; border-radius: 3px; color: #D32F2F;'>enumerate()</code> function, which returns an <strong style='color: #E91E63;'>enumerate object</strong> with index-value pairs.</p>

# %%
for item in myl:
    print(item)
# Out:
# 423.23434
# None
# ['python', 'ML']
# new value
# iti
# 234
# Commun.
# PS
# Tesing
# ['Commun.', 'PS', 'Tesing']

# %% [markdown]
# <h2 style='color: #9B59B6; background: linear-gradient(135deg, #F3E5F5 0%, #E1BEE7 100%); padding: 15px; border-radius: 8px; border-left: 5px solid #9C27B0;'>🔄 Iterating with enumerate()</h2>
#
# <p style='color: #555; font-size: 14px; line-height: 1.6;'>This cell demonstrates how to use <code style='background: #F5F5F5; padding: 2px 6px; border-radius: 3px; color: #D32F2F;'>enumerate()</code> in a loop to get both <strong style='color: #E91E63;'>index and value</strong> simultaneously.</p>

# %%
# enumarate ?
counter = 0
for item in myl:
    print(f"{counter}: {item}")
    counter +=1
# Out:
# 0: 423.23434
# 1: None
# 2: ['python', 'ML']
# 3: new value
# 4: iti
# 5: 234
# 6: Commun.
# 7: PS
# 8: Tesing
# 9: ['Commun.', 'PS', 'Tesing']

# %% [markdown]
# <h2 style='color: #9B59B6; background: linear-gradient(135deg, #F3E5F5 0%, #E1BEE7 100%); padding: 15px; border-radius: 8px; border-left: 5px solid #9C27B0;'>⚠️ Index Out of Range Error</h2>
#
# <p style='color: #555; font-size: 14px; line-height: 1.6;'><strong style='color: #FF9800;'>⚠️ Error Example:</strong> This cell demonstrates that accessing an index that doesn't exist will raise an <em style='color: #9C27B0;'>IndexError</em>.</p>

# %%
mylenum = enumerate(myl)
print(mylenum)

# %% [markdown]
# <h2 style='color: #9B59B6; background: linear-gradient(135deg, #F3E5F5 0%, #E1BEE7 100%); padding: 15px; border-radius: 8px; border-left: 5px solid #9C27B0;'>📌 Insert at Invalid Index</h2>
#
# <p style='color: #555; font-size: 14px; line-height: 1.6;'>This cell shows that <code style='background: #F5F5F5; padding: 2px 6px; border-radius: 3px; color: #D32F2F;'>.insert()</code> with an index beyond the list length will <strong style='color: #E91E63;'>append the element</strong> to the end.</p>

# %%
for index, item in mylenum:
    print(index, item )
# Out:
# 0 423.23434
# 1 None
# 2 ['python', 'ML']
# 3 new value
# 4 iti
# 5 234
# 6 Commun.
# 7 PS
# 8 Tesing
# 9 ['Commun.', 'PS', 'Tesing']

# %% [markdown]
# <h2 style='color: #9B59B6; background: linear-gradient(135deg, #F3E5F5 0%, #E1BEE7 100%); padding: 15px; border-radius: 8px; border-left: 5px solid #9C27B0;'>🔗 Concatenating Lists</h2>
#
# <p style='color: #555; font-size: 14px; line-height: 1.6;'>This cell demonstrates <strong style='color: #E91E63;'>concatenating two lists</strong> using the <code style='background: #F5F5F5; padding: 2px 6px; border-radius: 3px; color: #D32F2F;'>+</code> operator, which creates a new list.</p>

# %%
for index, item in mylenum:
    print(index, item )

# %% [markdown]
# <h2 style='color: #9B59B6; background: linear-gradient(135deg, #F3E5F5 0%, #E1BEE7 100%); padding: 15px; border-radius: 8px; border-left: 5px solid #9C27B0;'>📊 Finding Minimum Value</h2>
#
# <p style='color: #555; font-size: 14px; line-height: 1.6;'>This cell demonstrates using the <code style='background: #F5F5F5; padding: 2px 6px; border-radius: 3px; color: #D32F2F;'>min()</code> function to find the <strong style='color: #E91E63;'>smallest value</strong> in a list.</p>

# %%
# update value at index
myl[100]='updated'
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[27], line 2
#       1 # update value at index
# ----> 2 myl[100]='updated'
#
# IndexError: list assignment index out of range

# %% [markdown]
# <h2 style='color: #9B59B6; background: linear-gradient(135deg, #F3E5F5 0%, #E1BEE7 100%); padding: 15px; border-radius: 8px; border-left: 5px solid #9C27B0;'>💡 Converting String to List</h2>
#
# <p style='color: #555; font-size: 14px; line-height: 1.6;'>This cell demonstrates the difference: <code style='background: #F5F5F5; padding: 2px 6px; border-radius: 3px; color: #D32F2F;'>list(string)</code> creates a list of <strong style='color: #E91E63;'>individual characters</strong>, while <code style='background: #F5F5F5; padding: 2px 6px; border-radius: 3px; color: #D32F2F;'>[string]</code> creates a list with the <em style='color: #9C27B0;'>entire string</em> as one element.</p>

# %%
myl.insert(100, 'inserted') # if index not exists = append

# %% [markdown]
# <h2 style='color: #9B59B6; background: linear-gradient(135deg, #F3E5F5 0%, #E1BEE7 100%); padding: 15px; border-radius: 8px; border-left: 5px solid #9C27B0;'>✂️ Splitting String into List</h2>
#
# <p style='color: #555; font-size: 14px; line-height: 1.6;'>This cell demonstrates the <code style='background: #F5F5F5; padding: 2px 6px; border-radius: 3px; color: #D32F2F;'>.split()</code> method, which <strong style='color: #E91E63;'>splits a string</strong> into a list of words (by default, splits on whitespace).</p>

# %%
# concat
m = ["abc", True, 40 ,66]
n = ["python", "test", "iti", 88]
z = m + n
print(z)
# Out:
# ['abc', True, 40, 66, 'python', 'test', 'iti', 88]

# %% [markdown]
# <h2 style='color: #9B59B6; background: linear-gradient(135deg, #F3E5F5 0%, #E1BEE7 100%); padding: 15px; border-radius: 8px; border-left: 5px solid #9C27B0;'>🔗 Joining List Elements into String</h2>
#
# <p style='color: #555; font-size: 14px; line-height: 1.6;'>This cell demonstrates the <code style='background: #F5F5F5; padding: 2px 6px; border-radius: 3px; color: #D32F2F;'>.join()</code> method, which <strong style='color: #E91E63;'>combines list elements</strong> into a single string using a specified separator.</p>

# %%
x = [5,66,77]
print(min(x))
# Out:
# 5

# %%
# tip
name = 'ahmed'
name1 = list(name)
print(name1)
name2 = [name]
print(name2)
# Out:
# ['a', 'h', 'm', 'e', 'd']
# ['ahmed']

# %%
msg = "We love ITI 423325"
msg = msg.split()
print(msg)

# %%
#
users= ["ahmed", "Mohamed", "Ali", "data"]
# convert list elements to one string
print("-".join(users))
# Out:
# ahmed-Mohamed-Ali-data
