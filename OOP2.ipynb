# %% [markdown]
# # Scratch Space
#
# Quick experiments for class demos. Feel free to keep temporary assignments, sanity checks, or pseudo-code here without affecting the main notebook.

# %%
name='test'

# %% [markdown]
# _Tip: duplicate this notebook if you want a clean slate before a live demo._
