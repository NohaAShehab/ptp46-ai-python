# %%
print("hello world")
# Out:
# hello world

# %%
for char in "iti":
    print(f"char = {char}")

print(f"-- after loop {char}")
# Out:
# char = i
# char = t
# char = i
# -- after loop i

# %%
def sumnum(num1, num2):
    res = num1 + num2
    print(res)

sumnum(23,44) # sumnum
# Out:
# 67

# %%
sumnum("Ahmed", "ali") # concat
# Out:
# Ahmedali

# %%
sumnum([33], ["test"])
# Out:
# [33, 'test']

# %%
sumnum("Ahmed", 10)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 sumnum("Ahmed", 10)
#
# Cell In[3], line 2, in sumnum(num1, num2)
#       1 def sumnum(num1, num2):
# ----> 2     res = num1 + num2
#       3     print(res)
#
# TypeError: can only concatenate str (not "int") to str

# %% [markdown]
# ## we use the type hints for doc. purpose

# %%
# We need to validate the params ??

def sumnum(num1:int, num2:int)->int:
    res = num1+ num2
    print(res)
    return res

sumnum(324,423)
# Out:
# 747

# %%
sumnum("Ahmed", "Ali") # type hints
# Out:
# AhmedAli

# %%
sumnum("iti", 10)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 sumnum("iti", 10)
#
# Cell In[7], line 4, in sumnum(num1, num2)
#       3 def sumnum(num1:int, num2:int)->int:
# ----> 4     res = num1+ num2
#       5     print(res)
#
# TypeError: can only concatenate str (not "int") to str

# %% [markdown]
# # You must do the validation on your own.

# %%
def sumnum(num1 :int, num2: int)->int :
    # add validation rules
    if type(num1)==int and isinstance(num2, int):
        res = num1+ num2
        return  res

    print("------ not valid values")

sumnum(23,323)
sumnum("#2", 34)
# Out:
# ------ not valid values
