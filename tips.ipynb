# %%
loginn = False
for i in range(3):
    passwordd = input("please enter password")
    if passwordd=='abc':
        loginn = True
        print("-- login succ, ")
        break
    print("------- please try again ")
if not loginn:
    print("------ account has been locked ---- ")
# Out:
# ------- please try again
# ------- please try again
# ------- please try again
# ------ account has been locked ----

# %% [markdown]
# <h2 style='color: #FF9800; background: linear-gradient(135deg, #FFF3E0 0%, #FFE0B2 100%); padding: 15px; border-radius: 8px; border-left: 5px solid #F57C00;'>🔐 Login Attempt with Flag Variable</h2>
#
# <p style='color: #555; font-size: 14px; line-height: 1.6;'>This cell demonstrates a <strong style='color: #E91E63;'>login system</strong> using a flag variable to track login status. The loop allows up to 3 password attempts.</p>

# %%
for i in range(3):
    passwordd = input("please enter password")
    if passwordd=='abc':
        print("-- login succ, ")
        break
    print("------- please try again ")
else:
    # this block will be executed if the loop completed
    print("------ account has been locked ---- ")
# Out:
# ------- please try again
# ------- please try again
# -- login succ,

# %% [markdown]
# <h2 style='color: #FF9800; background: linear-gradient(135deg, #FFF3E0 0%, #FFE0B2 100%); padding: 15px; border-radius: 8px; border-left: 5px solid #F57C00;'>✨ Using for-else Loop</h2>
#
# <p style='color: #555; font-size: 14px; line-height: 1.6;'>This cell demonstrates the <code style='background: #F5F5F5; padding: 2px 6px; border-radius: 3px; color: #D32F2F;'>for-else</code> construct. The <code style='background: #F5F5F5; padding: 2px 6px; border-radius: 3px; color: #D32F2F;'>else</code> block executes only if the loop <strong style='color: #E91E63;'>completes without breaking</strong>.</p>

# %%
"""
if(){
}  // dev phase --> notes

"""
track = "ai"
"""
pass is a null operation — when it is executed, nothing happens. It is useful as a placeholder when a statement is required syntactically, but no code needs to be executed, for example:
"""
if track:
    pass

if track:
    ...

if track:
    "dasfsf sdf"

# %% [markdown]
# <h2 style='color: #FF9800; background: linear-gradient(135deg, #FFF3E0 0%, #FFE0B2 100%); padding: 15px; border-radius: 8px; border-left: 5px solid #F57C00;'>💡 Using pass, Ellipsis, and String Statements</h2>
#
# <p style='color: #555; font-size: 14px; line-height: 1.6;'>This cell demonstrates three ways to create <strong style='color: #E91E63;'>placeholder statements</strong> in Python: <code style='background: #F5F5F5; padding: 2px 6px; border-radius: 3px; color: #D32F2F;'>pass</code>, <code style='background: #F5F5F5; padding: 2px 6px; border-radius: 3px; color: #D32F2F;'>...</code> (ellipsis), and string literals.</p>
