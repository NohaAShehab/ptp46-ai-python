# %%
mys = set()
mys2 = {"iti", "iti", 214, 24.324, 'iti', True, ("python", 'ML')}

# %% [markdown]
# <h2 style='color: #E91E63; background: linear-gradient(135deg, #FCE4EC 0%, #F8BBD0 100%); padding: 15px; border-radius: 8px; border-left: 5px solid #C2185B;'>📦 Creating Sets</h2>
#
# <p style='color: #555; font-size: 14px; line-height: 1.6;'>This cell demonstrates creating sets. Sets <strong style='color: #E91E63;'>automatically remove duplicates</strong> and can contain various data types. Sets use hashing for efficient storage.</p>

# %%
"""
remove duplicated
no-order
no index

set use hashing in storing values
"""

ss = {"Ahmed", "Ali", ["iti", "python"]}
print(ss)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 9
#       1 """
#       2 remove duplicated
#       3 no-order
#    (...)      6 set use hashing in storing values
#       7 """
# ----> 9 ss = {"Ahmed", "Ali", ["iti", "python"]}
#      10 print(ss)
#
# TypeError: unhashable type: 'list'

# %% [markdown]
# <h2 style='color: #E91E63; background: linear-gradient(135deg, #FCE4EC 0%, #F8BBD0 100%); padding: 15px; border-radius: 8px; border-left: 5px solid #C2185B;'>⚠️ Sets Only Accept Immutable Types</h2>
#
# <p style='color: #555; font-size: 14px; line-height: 1.6;'><strong style='color: #FF9800;'>⚠️ Error Example:</strong> This cell demonstrates that sets can only contain <em style='color: #9C27B0;'>immutable data types</em>. Lists are mutable and cannot be set elements.</p>

# %%
# set accept immutable datatypes --> depend on hashing in storing values

### is set mutable or immutable ??
mys.add("new element")
print(mys)
# Out:
# {'new element'}

# %% [markdown]
# <h2 style='color: #E91E63; background: linear-gradient(135deg, #FCE4EC 0%, #F8BBD0 100%); padding: 15px; border-radius: 8px; border-left: 5px solid #C2185B;'>➕ Adding Elements to Set</h2>
#
# <p style='color: #555; font-size: 14px; line-height: 1.6;'>This cell demonstrates the <code style='background: #F5F5F5; padding: 2px 6px; border-radius: 3px; color: #D32F2F;'>.add()</code> method, which <strong style='color: #E91E63;'>adds a single element</strong> to a set. Sets are mutable.</p>

# %%
mys2.add("any")

# %% [markdown]
# <h2 style='color: #E91E63; background: linear-gradient(135deg, #FCE4EC 0%, #F8BBD0 100%); padding: 15px; border-radius: 8px; border-left: 5px solid #C2185B;'>⚠️ Sets Cannot Contain Mutable Types</h2>
#
# <p style='color: #555; font-size: 14px; line-height: 1.6;'><strong style='color: #FF9800;'>⚠️ Error Example:</strong> This cell shows that sets cannot contain other sets (which are mutable) as elements.</p>

# %%
print(mys2)
# Out:
# {True, 214, ('python', 'ML'), 24.324, 'any', 'iti'}

# %% [markdown]
# <h2 style='color: #E91E63; background: linear-gradient(135deg, #FCE4EC 0%, #F8BBD0 100%); padding: 15px; border-radius: 8px; border-left: 5px solid #C2185B;'>🔍 Checking Membership in Set</h2>
#
# <p style='color: #555; font-size: 14px; line-height: 1.6;'>This cell demonstrates using the <code style='background: #F5F5F5; padding: 2px 6px; border-radius: 3px; color: #D32F2F;'>in</code> operator to check if a value <strong style='color: #E91E63;'>exists in the set</strong>.</p>

# %%
# set is mutable ===?

ss = {"dsfsdf", "Dasff", {1,True}}
print(ss)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 3
#       1 # set is mutable ===?
# ----> 3 ss = {"dsfsdf", "Dasff", {1,True}}
#       4 print(ss)
#
# TypeError: unhashable type: 'set'

# %% [markdown]
# <h2 style='color: #E91E63; background: linear-gradient(135deg, #FCE4EC 0%, #F8BBD0 100%); padding: 15px; border-radius: 8px; border-left: 5px solid #C2185B;'>🗑️ Removing Elements with pop()</h2>
#
# <p style='color: #555; font-size: 14px; line-height: 1.6;'>This cell demonstrates the <code style='background: #F5F5F5; padding: 2px 6px; border-radius: 3px; color: #D32F2F;'>.pop()</code> method, which <strong style='color: #E91E63;'>removes and returns</strong> an arbitrary element from the set (since sets are unordered).</p>

# %%
ss = {"sfsfd", "Aff", "Fsdfsf"}
print(ss)

print(ss)
# Out:
# {'Aff', 'Fsdfsf', 'sfsfd'}
# {'Aff', 'Fsdfsf', 'sfsfd'}

# %% [markdown]
# <h2 style='color: #E91E63; background: linear-gradient(135deg, #FCE4EC 0%, #F8BBD0 100%); padding: 15px; border-radius: 8px; border-left: 5px solid #C2185B;'>🗑️ Removing Specific Elements with remove()</h2>
#
# <p style='color: #555; font-size: 14px; line-height: 1.6;'>This cell demonstrates the <code style='background: #F5F5F5; padding: 2px 6px; border-radius: 3px; color: #D32F2F;'>.remove()</code> method, which <strong style='color: #E91E63;'>removes a specific element</strong> from the set. Raises KeyError if element doesn't exist.</p>

# %%
print("noha" in ss)
# Out:
# False

# %%
ss.add("python")

# %%
print(ss)
# Out:
# {'Aff', 'Fsdfsf', 'sfsfd', 'python'}

# %%
ss.add("ML")
print(ss)
# Out:
# {'ML', 'sfsfd', 'Aff', 'python', 'Fsdfsf'}

# %%
popped_value=ss.pop()
print(popped_value)
print(ss)
# Out:
# ML
# {'sfsfd', 'Aff', 'python', 'Fsdfsf'}

# %%
print(ss)
# Out:
# {'sfsfd', 'Aff', 'python', 'Fsdfsf'}

# %%
ss.pop()
# Out:
# 'sfsfd'

# %%
ss.remove("Python")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 ss.remove("Python")
#
# KeyError: 'Python'

# %%
ss.remove("python")

# %%
print(ss)
# Out:
# {'Aff', 'Fsdfsf'}
